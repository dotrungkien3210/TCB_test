# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/tcb
# !ls
# Out:
# /content/drive/MyDrive/tcb
# data.csv  ex1  ex2  ex3  linear.ipynb

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from sklearn.preprocessing import PolynomialFeatures
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv('data.csv')

# %%
data
# Out:
#                                   Movie Release Date  Critic 1  Critic 2  \
# 0                              Iron Man     2-May-08       4.0       4.0
# 1                   The Incredible Hulk    13-Jun-08       NaN       NaN
# 2                            Iron Man 2     7-May-10       3.0       6.0
# 3                                  Thor     6-May-11       4.0       6.0
# 4    Captain America: The First Avenger    22-Jul-11       5.0       5.0
# 5                 Marvel's The Avengers     4-May-12       3.0       8.0
# 6                            Iron Man 3     3-May-13       3.0       NaN
# 7                  Thor: The Dark World     8-Nov-13       3.0       3.0
# 8   Captain America: The Winter Soldier     4-Apr-14       7.0       7.0
# 9               Guardians of the Galaxy     1-Aug-14       5.0       6.0
# 10              Avengers: Age of Ultron     1-May-15       NaN       4.0
# 11                              Ant-Man    17-Jul-15       3.0       5.0
# 12           Captain America: Civil War     6-May-16       7.0       NaN
# 13                       Doctor Strange     4-Nov-16       4.0       6.0
# 14       Guardians of the Galaxy Vol. 2     5-May-17       7.0      10.0
# 15               Spider-Man: Homecoming     7-Jul-17       NaN       9.0
# 16                       Thor: Ragnarok     3-Nov-17       NaN      10.0
# 17                        Black Panther    16-Feb-18       NaN       7.0
# 18               Avengers: Infinity War    27-Apr-18       7.0       7.0
# 19                 Ant-Man and the Wasp     6-Jul-18       NaN       8.0
# 20                       Captain Marvel     8-Mar-19       5.0       NaN
# 21                    Avengers: Endgame    26-Apr-19       6.0       9.0
#
#     Critic 3  Critic 4  Critic 5  Audience Rating
# 0        7.0       6.0       5.0              9.1
# 1        6.0       3.0       5.0              7.0
# 2        8.0       6.0       5.0              7.1
# 3        8.0       5.0       NaN              7.6
# 4        NaN       7.0       7.0              7.5
# 5        8.0       NaN       9.0              9.1
# 6        8.0       NaN       5.0              7.8
# 7        9.0       5.0       5.0              7.5
# 8        9.0       9.0       NaN              9.2
# 9        NaN       9.0       8.0              9.2
# 10       7.0       NaN       NaN              8.3
# 11       6.0       NaN       4.0              8.5
# 12       8.0       9.0       NaN              8.9
# 13       8.0       NaN       5.0              8.6
# 14       7.0       5.0      10.0              8.7
# 15       NaN       8.0       8.0              8.7
# 16       5.0       9.0       NaN              8.7
# 17       6.0       6.0       8.0              7.9
# 18       9.0       8.0       9.0              9.1
# 19       6.0       7.0       NaN              8.1
# 20       9.0       5.0       NaN              4.5
# 21      10.0      10.0      10.0              9.0

# %%
data.describe()
# Out:
#         Critic 1   Critic 2   Critic 3   Critic 4   Critic 5  Audience Rating
# count  16.000000  18.000000  19.000000  17.000000  15.000000        22.000000
# mean    4.750000   6.666667   7.578947   6.882353   6.866667         8.186364
# std     1.612452   2.057983   1.346427   1.964763   2.099887         1.080254
# min     3.000000   3.000000   5.000000   3.000000   4.000000         4.500000
# 25%     3.000000   5.250000   6.500000   5.000000   5.000000         7.650000
# 50%     4.500000   6.500000   8.000000   7.000000   7.000000         8.550000
# 75%     6.250000   8.000000   8.500000   9.000000   8.500000         8.975000
# max     7.000000  10.000000  10.000000  10.000000  10.000000         9.200000

# %%
# Drop cột ko liên quan
data = data.drop(columns = ['Movie', 'Release Date'])

# %%
train, test = train_test_split(data, test_size = 0.2, random_state = 42)

# %%
for column in train.columns:
    col_mode = train[column].mean()
    train[column].fillna(col_mode, inplace = True)

for column in test.columns:
    col_mode = test[column].mean()
    test[column].fillna(col_mode, inplace = True)

# %%
train
# Out:
#     Critic 1   Critic 2  Critic 3  Critic 4   Critic 5  Audience Rating
# 5   3.000000   8.000000       8.0       7.0   9.000000              9.1
# 20  5.000000   6.714286       9.0       5.0   7.272727              4.5
# 11  3.000000   5.000000       6.0       7.0   4.000000              8.5
# 3   4.000000   6.000000       8.0       5.0   7.272727              7.6
# 4   5.000000   5.000000       7.6       7.0   7.000000              7.5
# 17  4.692308   7.000000       6.0       6.0   8.000000              7.9
# 12  7.000000   6.714286       8.0       9.0   7.272727              8.9
# 18  7.000000   7.000000       9.0       8.0   9.000000              9.1
# 16  4.692308  10.000000       5.0       9.0   7.272727              8.7
# 2   3.000000   6.000000       8.0       6.0   5.000000              7.1
# 9   5.000000   6.000000       7.6       9.0   8.000000              9.2
# 21  6.000000   9.000000      10.0      10.0  10.000000              9.0
# 7   3.000000   3.000000       9.0       5.0   5.000000              7.5
# 10  4.692308   4.000000       7.0       7.0   7.272727              8.3
# 14  7.000000  10.000000       7.0       5.0  10.000000              8.7
# 19  4.692308   8.000000       6.0       7.0   7.272727              8.1
# 6   3.000000   6.714286       8.0       7.0   5.000000              7.8

# %%
test
# Out:
#     Critic 1  Critic 2  Critic 3  Critic 4  Critic 5  Audience Rating
# 0        4.0       4.0       7.0       6.0      5.00              9.1
# 13       4.0       6.0       8.0       6.5      5.00              8.6
# 8        7.0       7.0       9.0       9.0      5.75              9.2
# 1        5.0       6.5       6.0       3.0      5.00              7.0
# 15       5.0       9.0       7.5       8.0      8.00              8.7

# %%
# Mũ lên
poly = PolynomialFeatures(degree = 5)

# Tạo df mới(ko có cột target)
train_new = train.drop(columns = ['Audience Rating'])
test_new = test.drop(columns = ['Audience Rating'])

# Transform df
train_new = poly.fit_transform(train_new)
test_new = poly.transform(test_new)
print('Polynomial Features shape: ', train_new.shape)
# Out:
# Polynomial Features shape:  (17, 252)

# %%
poly.get_feature_names(input_features = ['Critic 1',	'Critic 2', 'Critic 3',	'Critic 4', 'Critic 5'])[:50]
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# ['1',
#  'Critic 1',
#  'Critic 2',
#  'Critic 3',
#  'Critic 4',
#  'Critic 5',
#  'Critic 1^2',
#  'Critic 1 Critic 2',
#  'Critic 1 Critic 3',
#  'Critic 1 Critic 4',
#  'Critic 1 Critic 5',
#  'Critic 2^2',
#  'Critic 2 Critic 3',
#  'Critic 2 Critic 4',
#  'Critic 2 Critic 5',
#  'Critic 3^2',
#  'Critic 3 Critic 4',
#  'Critic 3 Critic 5',
#  'Critic 4^2',
#  'Critic 4 Critic 5',
#  'Critic 5^2',
#  'Critic 1^3',
#  'Critic 1^2 Critic 2',
#  'Critic 1^2 Critic 3',
#  'Critic 1^2 Critic 4',
#  'Critic 1^2 Critic 5',
#  'Critic 1 Critic 2^2',
#  'Critic 1 Critic 2 Critic 3',
#  'Critic 1 Critic 2 Critic 4',
#  'Critic 1 Critic 2 Critic 5',
#  'Critic 1 Critic 3^2',
#  'Critic 1 Critic 3 Critic 4',
#  'Critic 1 Critic 3 Critic 5',
#  'Critic 1 Critic 4^2',
#  'Critic 1 Critic 4 Critic 5',
#  'Critic 1 Critic 5^2',
#  'Critic 2^3',
#  'Critic 2^2 Critic 3',
#  'Critic 2^2 Critic 4',
#  'Critic 2^2 Critic 5',
#  'Critic 2 Critic 3^2',
#  'Critic 2 Critic 3 Critic 4',
#  'Critic 2 Critic 3 Critic 5',
#  'Critic 2 Critic 4^2',
#  'Critic 2 Critic 4 Critic 5',
#  'Critic 2 Critic 5^2',
#  'Critic 3^3',
#  'Critic 3^2 Critic 4',
#  'Critic 3^2 Critic 5',
#  'Critic 3 Critic 4^2']

# %%
poly_train = pd.DataFrame(train_new, 
                             columns = poly.get_feature_names(['Critic 1',	'Critic 2', 'Critic 3',	'Critic 4', 'Critic 5']))

poly_train['TARGET'] = train['Audience Rating']

# Tính correlation
poly_corrs = poly_train.corr()['TARGET'].sort_values()

print(poly_corrs.head(10))
print(poly_corrs.tail(5))
# Out:
# Critic 1 Critic 4              -0.272666
# Critic 1^3 Critic 4^2          -0.269221
# Critic 1^3 Critic 3 Critic 4   -0.265536
# Critic 1^2 Critic 4            -0.264747
# Critic 1^4 Critic 4            -0.262810
# Critic 1^3 Critic 4            -0.262611
# Critic 4                       -0.261710
# Critic 1^2 Critic 4^2          -0.260854
# Critic 1^2 Critic 3 Critic 4   -0.254859
# Critic 1 Critic 4^2            -0.252155
# Name: TARGET, dtype: float64
# Critic 2^3    0.258534
# Critic 2^5    0.263435
# Critic 2^4    0.264910
# TARGET        1.000000
# 1                  NaN
# Name: TARGET, dtype: float64
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
poly_train
# Out:
#       1  Critic 1   Critic 2  Critic 3  Critic 4   Critic 5  Critic 1^2  \
# 0   1.0  3.000000   8.000000       8.0       7.0   9.000000    9.000000
# 1   1.0  5.000000   6.714286       9.0       5.0   7.272727   25.000000
# 2   1.0  3.000000   5.000000       6.0       7.0   4.000000    9.000000
# 3   1.0  4.000000   6.000000       8.0       5.0   7.272727   16.000000
# 4   1.0  5.000000   5.000000       7.6       7.0   7.000000   25.000000
# 5   1.0  4.692308   7.000000       6.0       6.0   8.000000   22.017751
# 6   1.0  7.000000   6.714286       8.0       9.0   7.272727   49.000000
# 7   1.0  7.000000   7.000000       9.0       8.0   9.000000   49.000000
# 8   1.0  4.692308  10.000000       5.0       9.0   7.272727   22.017751
# 9   1.0  3.000000   6.000000       8.0       6.0   5.000000    9.000000
# 10  1.0  5.000000   6.000000       7.6       9.0   8.000000   25.000000
# 11  1.0  6.000000   9.000000      10.0      10.0  10.000000   36.000000
# 12  1.0  3.000000   3.000000       9.0       5.0   5.000000    9.000000
# 13  1.0  4.692308   4.000000       7.0       7.0   7.272727   22.017751
# 14  1.0  7.000000  10.000000       7.0       5.0  10.000000   49.000000
# 15  1.0  4.692308   8.000000       6.0       7.0   7.272727   22.017751
# 16  1.0  3.000000   6.714286       8.0       7.0   5.000000    9.000000
#
#     Critic 1 Critic 2  Critic 1 Critic 3  Critic 1 Critic 4  ...  \
# 0           24.000000          24.000000          21.000000  ...
# 1           33.571429          45.000000          25.000000  ...
# 2           15.000000          18.000000          21.000000  ...
# 3           24.000000          32.000000          20.000000  ...
# 4           25.000000          38.000000          35.000000  ...
# 5           32.846154          28.153846          28.153846  ...
# 6           47.000000          56.000000          63.000000  ...
# 7           49.000000          63.000000          56.000000  ...
# 8           46.923077          23.461538          42.230769  ...
# 9           18.000000          24.000000          18.000000  ...
# 10          30.000000          38.000000          45.000000  ...
# 11          54.000000          60.000000          60.000000  ...
# 12           9.000000          27.000000          15.000000  ...
# 13          18.769231          32.846154          32.846154  ...
# 14          70.000000          49.000000          35.000000  ...
# 15          37.538462          28.153846          32.846154  ...
# 16          20.142857          24.000000          21.000000  ...
#
#     Critic 3 Critic 4^2 Critic 5^2  Critic 3 Critic 4 Critic 5^3  \
# 0                     31752.000000                  40824.000000
# 1                     11900.826446                  17310.293013
# 2                      4704.000000                   2688.000000
# 3                     10578.512397                  15386.927122
# 4                     18247.600000                  18247.600000
# 5                     13824.000000                  18432.000000
# 6                     34274.380165                  27696.468820
# 7                     46656.000000                  52488.000000
# 8                     21421.487603                  17310.293013
# 9                      7200.000000                   6000.000000
# 10                    39398.400000                  35020.800000
# 11                   100000.000000                 100000.000000
# 12                     5625.000000                   5625.000000
# 13                    18142.148760                  18848.985725
# 14                    17500.000000                  35000.000000
# 15                    15550.413223                  16156.273479
# 16                     9800.000000                   7000.000000
#
#     Critic 3 Critic 5^4  Critic 4^5  Critic 4^4 Critic 5  \
# 0          52488.000000     16807.0         21609.000000
# 1          25178.608019      3125.0          4545.454545
# 2           1536.000000     16807.0          9604.000000
# 3          22380.984905      3125.0          4545.454545
# 4          18247.600000     16807.0         16807.000000
# 5          24576.000000      7776.0         10368.000000
# 6          22380.984905     59049.0         47716.363636
# 7          59049.000000     32768.0         36864.000000
# 8          13988.115566     59049.0         47716.363636
# 9           5000.000000      7776.0          6480.000000
# 10         31129.600000     59049.0         52488.000000
# 11        100000.000000    100000.0        100000.000000
# 12          5625.000000      3125.0          3125.000000
# 13         19583.361792     16807.0         17461.818182
# 14         70000.000000      3125.0          6250.000000
# 15         16785.738679     16807.0         17461.818182
# 16          5000.000000     16807.0         12005.000000
#
#     Critic 4^3 Critic 5^2  Critic 4^2 Critic 5^3  Critic 4 Critic 5^4  \
# 0            27783.000000           35721.000000         45927.000000
# 1             6611.570248            9616.829452         13988.115566
# 2             5488.000000            3136.000000          1792.000000
# 3             6611.570248            9616.829452         13988.115566
# 4            16807.000000           16807.000000         16807.000000
# 5            13824.000000           18432.000000         24576.000000
# 6            38558.677686           31158.527423         25178.608019
# 7            41472.000000           46656.000000         52488.000000
# 8            38558.677686           31158.527423         25178.608019
# 9             5400.000000            4500.000000          3750.000000
# 10           46656.000000           41472.000000         36864.000000
# 11          100000.000000          100000.000000        100000.000000
# 12            3125.000000            3125.000000          3125.000000
# 13           18142.148760           18848.985725         19583.361792
# 14           12500.000000           25000.000000         50000.000000
# 15           18142.148760           18848.985725         19583.361792
# 16            8575.000000            6125.000000          4375.000000
#
#        Critic 5^5  TARGET
# 0    59049.000000     NaN
# 1    20346.349914     NaN
# 2     1024.000000     7.1
# 3    20346.349914     7.6
# 4    16807.000000     7.5
# 5    32768.000000     9.1
# 6    20346.349914     7.8
# 7    59049.000000     7.5
# 8    20346.349914     NaN
# 9     3125.000000     9.2
# 10   32768.000000     8.3
# 11  100000.000000     8.5
# 12    3125.000000     8.9
# 13   20346.349914     NaN
# 14  100000.000000     8.7
# 15   20346.349914     NaN
# 16    3125.000000     8.7
#
# [17 rows x 253 columns]
